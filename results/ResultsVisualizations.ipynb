# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# @title Configure directories
from pathlib import Path

# @markdown Path to results.csv
results = '/content/gdrive/MyDrive/CSC 570 - GAMES/CSC570 - Project/results.csv' # @param {type: 'string'}

# %%
import pandas as pd

# %%
df = pd.read_csv(results, index_col=0)
df.head(100)
# Out:
#                    a1                          a2       d1       d2  wins  \
# 0        Random Agent                Greedy Agent     Mage     Mage     0
# 1        Random Agent                Greedy Agent     Mage  Warrior     8
# 2        Random Agent                Greedy Agent     Mage   Shaman     1
# 3        Random Agent                Greedy Agent  Warrior     Mage    34
# 4        Random Agent                Greedy Agent  Warrior  Warrior     7
# ..                ...                         ...      ...      ...   ...
# 85  2 Step Look Ahead  Weighted 2 Step Look Ahead  Warrior  Warrior    75
# 86  2 Step Look Ahead  Weighted 2 Step Look Ahead  Warrior   Shaman    67
# 87  2 Step Look Ahead  Weighted 2 Step Look Ahead   Shaman     Mage    82
# 88  2 Step Look Ahead  Weighted 2 Step Look Ahead   Shaman  Warrior    81
# 89  2 Step Look Ahead  Weighted 2 Step Look Ahead   Shaman   Shaman    87
#
#     loses  ties    wr
# 0     100     0  0.00
# 1      92     0  0.08
# ...

# %%
df_mirror = df.copy()
df_mirror.head(3)
for i in df_mirror.index:
    df_mirror['a1'][i], df_mirror['a2'][i] = df_mirror['a2'][i], df_mirror['a1'][i]
    df_mirror['d1'][i], df_mirror['d2'][i] = df_mirror['d2'][i], df_mirror['d1'][i]
    df_mirror['wins'][i], df_mirror['loses'][i] = df_mirror['loses'][i], df_mirror['wins'][i]
    df_mirror['wr'][i] = 1 - df_mirror['wr'][i]

df_mirror.head(10)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# ...

# %%
df_com = df.append(df_mirror, ignore_index=True)

# %%
deck_matchups = df_com.groupby(by=['d1','d2']).mean()
deck_matchups = deck_matchups.drop(columns=['wins', 'loses', 'ties'])
deck_matchups.head(9)
# Out:
#                        wr
# d1      d2
# Mage    Mage     0.500000
#         Shaman   0.448298
#         Warrior  0.520871
# Shaman  Mage     0.551702
#         Shaman   0.500000
#         Warrior  0.513323
# Warrior Mage     0.479129
#         Shaman   0.486677
#         Warrior  0.500000

# %%
agent_matchups = df_com.groupby(by=['a1','a2']).mean()
agent_matchups = agent_matchups.drop(columns=['wins', 'loses', 'ties'])
agent_matchups.head(100)
# Out:
#                                                              wr
# a1                         a2
# 2 Step Look Ahead          Greedy Agent                0.843333
#                            MCTS                        0.488889
#                            Random Agent                0.998889
#                            Weighted 2 Step Look Ahead  0.738395
# Greedy Agent               2 Step Look Ahead           0.156667
#                            MCTS                        0.158889
#                            Random Agent                0.871111
#                            Weighted 2 Step Look Ahead  0.380195
# MCTS                       2 Step Look Ahead           0.511111
#                            Greedy Agent                0.841111
#                            Random Agent                0.994444
#                            Weighted 2 Step Look Ahead  0.688485
# Random Agent               2 Step Look Ahead           0.001111
# ...

# %%
agentdecks_matchups = df_com.groupby(by=['a1','d1','d2']).mean()
agentdecks_matchups = agentdecks_matchups.drop(columns=['wins', 'loses', 'ties'])
agentdecks_matchups.head(100)
# Out:
#                                                   wr
# a1                         d1      d2
# 2 Step Look Ahead          Mage    Mage     0.722500
#                                    Shaman   0.757500
#                                    Warrior  0.867500
#                            Shaman  Mage     0.767500
#                                    Shaman   0.775000
#                                    Warrior  0.812500
#                            Warrior Mage     0.653889
#                                    Shaman   0.737500
#                                    Warrior  0.812500
# Greedy Agent               Mage    Mage     0.446035
#                                    Shaman   0.350000
#                                    Warrior  0.306020
#                            Shaman  Mage     0.505000
#                                    Shaman   0.545000
#                                    Warrior  0.332500
#                            Warrior Mage     0.355000
# ...
